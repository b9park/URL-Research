# %% [markdown]
# Geo code
# * geo code for brazil
# * Goal: tale scrape long, lat
# * scrape and verify if its lat and long

# %%
API_KEY = "AIzaSyD_-qwjnfnhTBczSUftL_bGroJ1lJk1z0k"

# %%
import pandas as pd 
import requests 
import time

file = 'UgandaColleges.csv'
df = pd.read_csv('UgandaColleges.csv')
df
# Out:
#     Unnamed: 0                                            college  unitype  \
# 0            0                                Busitema University   public
# 1            1                                    Gulu University   public
# 2            2                                  Kabale University   public
# 3            3          Valley University of Science & Technology  private
# 4            4                                Victoria University  private
# 5            5                       Virtual University of Uganda  private
# 6            6                                Kyambogo University   public
# 7            7                                    Lira University   public
# 8            8                                Makerere University   public
# 9            9       Mbarara University of Science and Technology   public
# 10          10                                    Muni University   public
# ...

# %%
address = 'Stafford University'
params = { "key": API_KEY,
          'address': address
    
}
base_url = 'https://maps.googleapis.com/maps/api/geocode/json?'
response = requests.get(base_url,params= params).json()
response.keys()
if response['status']== 'OK':
    geo = response['results'][0]['geometry']
    latitude = geo['location']['lat']
    longitude = geo['location']['lng']
print(latitude,longitude)
# Out:
# 2.7702486 32.2665176

# %%
## new one 

def get_latitude(row):
    address = row['college']
    
    if pd.isna(address) or address == 'nan':
        return None

    params = {'key': API_KEY, 'address': address}
    base_url = 'https://maps.googleapis.com/maps/api/geocode/json?'

    try:
        response = requests.get(base_url, params=params).json()
        if response['status'] == 'OK':
            geo = response['results'][0]['geometry']
            latitude = geo['location']['lat']
            return latitude
        else:
            print(f"Address '{address}' returned status {response['status']} for row index {row.name}")
            return None
    except Exception as e:
        print(f"Error fetching latitude for address '{address}' at row index {row.name}: {e}")
        return None
    finally:
        # Delay for 0.1 seconds (or any other suitable duration)
        time.sleep(1)

df['new_latitude'] = df.apply(get_latitude, axis=1)
# Out:
# Address 'Valley University of Science & Technology' returned status ZERO_RESULTS for row index 3
# Address 'Victoria University' returned status ZERO_RESULTS for row index 4
# Address 'Cavendish University' returned status ZERO_RESULTS for row index 21
# Address 'International Business, Science, & Technology University' returned status ZERO_RESULTS for row index 25
# Address 'Nkumba University' returned status ZERO_RESULTS for row index 39
# Address 'Stafford University' returned status ZERO_RESULTS for row index 44
# Address 'Team University' returned status ZERO_RESULTS for row index 45

# %%
# Out:
# Processed row index 0: 0.5452743999999999, 34.0200286
# Processed row index 1: 2.7881388, 32.3168635
# Processed row index 2: -1.2722888, 29.9882291
# Address 'Valley University of Science & Technology' returned status ZERO_RESULTS at row index 3
# Address 'Victoria University' returned status ZERO_RESULTS at row index 4
# Processed row index 5: 1.373333, 32.290275
# Processed row index 6: 0.3473946, 32.6320734
# Processed row index 7: 2.2509766, 32.8210473
# Processed row index 8: 0.3326347, 32.5685861
# Processed row index 9: -0.6167245, 30.656788
# Processed row index 10: 2.996229, 30.926812
# Processed row index 11: 1.7655341, 33.627388
# Processed row index 12: 0.3261291, 32.4410553
# Processed row index 13: 0.2410963, 32.564848
# Processed row index 14: 0.9400761, 30.8125638
# Processed row index 15: 24.8920491, 67.0735131
# Processed row index 16: 2.2461198, 32.8997326
# Processed row index 17: -0.5738371999999999, 30.3813038
# Processed row index 18: 0.3572723, 32.541461
# ...

# %%
df
# Out:
#     Unnamed: 0                                            college  unitype  \
# 0            0                                Busitema University   public
# 1            1                                    Gulu University   public
# 2            2                                  Kabale University   public
# 3            3          Valley University of Science & Technology  private
# 4            4                                Victoria University  private
# 5            5                       Virtual University of Uganda  private
# 6            6                                Kyambogo University   public
# 7            7                                    Lira University   public
# 8            8                                Makerere University   public
# 9            9       Mbarara University of Science and Technology   public
# 10          10                                    Muni University   public
# ...

# %%
def get_lat(row):
    address = row['college']
   
    params = { "key": API_KEY,
          'address': address}
    base_url = 'https://maps.googleapis.com/maps/api/geocode/json?'
    response = requests.get(base_url,params= params).json()
    response.keys()
    if response['status']== 'OK':
        geo = response['results'][0]['geometry']
        latitude = geo['location']['lat']
        longitude = geo['location']['lng']
    return latitude

# %%
df['college'].iloc[3]
# Out:
# 'Valley University of Science & Technology'

# %%
df['new_latitude'] = df['college'].apply(get_lat)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 df['new_latitude'] = df['college'].apply(get_lat)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:4771, in Series.apply(self, func, convert_dtype, args, **kwargs)
#    4661 def apply(
#    4662     self,
#    4663     func: AggFuncType,
#    (...)
#    4666     **kwargs,
#    4667 ) -> DataFrame | Series:
#    4668     """
#    4669     Invoke function on values of Series.
#    4670
#    (...)
#    4769     dtype: float64
#    4770     """
# -> 4771     return SeriesApply(self, func, convert_dtype, args, kwargs).apply()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:1123, in SeriesApply.apply(self)
#    1120     return self.apply_str()
#    1122 # self.f is Callable
# -> 1123 return self.apply_standard()
#
# ...

# %%
df
# Out:
#     Unnamed: 0                                            college  unitype  \
# 0            0                                Busitema University   public
# 1            1                                    Gulu University   public
# 2            2                                  Kabale University   public
# 3            3          Valley University of Science & Technology  private
# 4            4                                Victoria University  private
# 5            5                       Virtual University of Uganda  private
# 6            6                                Kyambogo University   public
# 7            7                                    Lira University   public
# 8            8                                Makerere University   public
# 9            9       Mbarara University of Science and Technology   public
# 10          10                                    Muni University   public
# ...

# %%
import requests
import time

def get_latitude(row):
    latitude = None
    address = row
    params = {'key': API_KEY, 'address': address}
    base_url = 'https://maps.googleapis.com/maps/api/geocode/json?'

    for attempt in range(9):  # Try up to 3 attempts
        try:
            response = requests.get(base_url, params=params).json()
            if response['status'] == 'OK':
                geo = response['results'][0]['geometry']
                latitude = geo['location']['lat']
                break  # Exit loop if successful
            elif response['status'] == 'OVER_QUERY_LIMIT':
                print("Rate limit exceeded, waiting to retry...")
                time.sleep(4)  # Wait for 2 seconds before retrying
            else:
                print(f"Error or no result for address '{address}': {response['status']}")
                break  # Exit loop if an error other than rate limit exceeded
        except Exception as e:
            print(f"Exception fetching latitude for address '{address}': {e}")
            time.sleep(2)  # Wait for 2 seconds before retrying

    return latitude
df['new_latitude'] = df['college'].apply(get_latitude)
# Out:
# Error or no result for address 'Valley University of Science & Technology': ZERO_RESULTS
# Error or no result for address 'Victoria University': ZERO_RESULTS
# Error or no result for address 'Cavendish University': ZERO_RESULTS
# Error or no result for address 'International Business, Science, & Technology University': ZERO_RESULTS
# Error or no result for address 'Nkumba University': ZERO_RESULTS
# Error or no result for address 'Stafford University': ZERO_RESULTS
# Error or no result for address 'Team University': ZERO_RESULTS
# Error or no result for address 'nan': ZERO_RESULTS
# Error or no result for address 'nan': ZERO_RESULTS
# Error or no result for address 'nan': ZERO_RESULTS

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# college          object
# unitype          object
# estyr           float64
# district         object
# latitude        float64
# longitude       float64
# city             object
# new_latitude    float64
# dtype: object

# %%
print((0.5452743999999999-0.545462 ),( 34.0200286-34.020027))                #   0.545462 34.020027 0.545462	34.020027
# Out:
# -0.0001876000000000655 1.6000000044869012e-06

# %%
0.5452743999999999        34.0200286
# Out:
# -0.0005462000000000522

# %%
response['results'][0]['geometry']
# Out:
# {'location': {'lat': 2.7881388, 'lng': 32.3168635},
#  'location_type': 'GEOMETRIC_CENTER',
#  'viewport': {'northeast': {'lat': 2.789590480291502,
#    'lng': 32.31824608029149},
#   'southwest': {'lat': 2.786892519708498, 'lng': 32.3155481197085}}}

# %%
def lat(df):
    df.

# %%
1.6000000044869012e-06
# Out:
# 1.6000000044869012e-06
